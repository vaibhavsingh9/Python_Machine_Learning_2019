# %%
# !git clone https://github.com/huggingface/transfer-learning-conv-ai
# Out:
# Cloning into 'transfer-learning-conv-ai'...
# remote: Enumerating objects: 110, done.
# remote: Total 110 (delta 0), reused 0 (delta 0), pack-reused 110
# Receiving objects: 100% (110/110), 48.83 KiB | 420.00 KiB/s, done.
# Resolving deltas: 100% (60/60), done.

# %%
cd transfer-learning-conv-ai
# Out:
# /content/transfer-learning-conv-ai

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (1.5.1+cu101)
# Collecting pytorch-ignite
#   Downloading https://files.pythonhosted.org/packages/35/55/41e8a995876fd2ade29bdba0c3efefa38e7d605cb353c70f3173c04928b5/pytorch_ignite-0.3.0-py2.py3-none-any.whl (103kB)
#      |████████████████████████████████| 112kB 4.7MB/s
# Collecting transformers==2.5.1
#   Downloading https://files.pythonhosted.org/packages/13/33/ffb67897a6985a7b7d8e5e7878c3628678f553634bd3836404fef06ef19b/transformers-2.5.1-py3-none-any.whl (499kB)
#      |████████████████████████████████| 501kB 8.7MB/s
# Collecting tensorboardX==1.8
#   Downloading https://files.pythonhosted.org/packages/c3/12/dcaf67e1312475b26db9e45e7bb6f32b540671a9ee120b3a72d9e09bc517/tensorboardX-1.8-py2.py3-none-any.whl (216kB)
#      |████████████████████████████████| 225kB 12.0MB/s
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->-r requirements.txt (line 1)) (1.18.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers==2.5.1->-r requirements.txt (line 3)) (3.0.12)
# Collecting tokenizers==0.5.2
#   Downloading https://files.pythonhosted.org/packages/d1/3f/73c881ea4723e43c1e9acf317cf407fab3a278daab3a69c98dcac511c04f/tokenizers-0.5.2-cp36-cp36m-manylinux1_x86_64.whl (3.7MB)
#      |████████████████████████████████| 3.7MB 15.1MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 46.9MB/s
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from transformers==2.5.1->-r requirements.txt (line 3)) (1.14.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers==2.5.1->-r requirements.txt (line 3)) (4.41.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==2.5.1->-r requirements.txt (line 3)) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==2.5.1->-r requirements.txt (line 3)) (2.23.0)
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/d4/a4/d0a884c4300004a78cca907a6ff9a5e9fe4f090f5d95ab341c53d28cbc58/sentencepiece-0.1.91-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 42.2MB/s
# Requirement already satisfied: protobuf>=3.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX==1.8->-r requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX==1.8->-r requirements.txt (line 4)) (1.12.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 5)) (1.29.0)
# Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 5)) (3.2.1)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 5)) (0.3.3)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 5)) (1.12.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 5)) (1.6.3)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 5)) (0.34.2)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 5)) (2.10.0)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 5)) (1.4.1)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 5)) (1.1.2)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow->-r requirements.txt (line 5)) (2.2.2)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.5.1->-r requirements.txt (line 3)) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.5.1->-r requirements.txt (line 3)) (0.15.1)
# Requirement already satisfied: botocore<1.18.0,>=1.17.5 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.5.1->-r requirements.txt (line 3)) (1.17.5)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.5.1->-r requirements.txt (line 3)) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers==2.5.1->-r requirements.txt (line 3)) (0.3.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.5.1->-r requirements.txt (line 3)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.5.1->-r requirements.txt (line 3)) (2020.4.5.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.5.1->-r requirements.txt (line 3)) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.5.1->-r requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.2.0->tensorboardX==1.8->-r requirements.txt (line 4)) (47.3.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow->-r requirements.txt (line 5)) (1.17.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow->-r requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow->-r requirements.txt (line 5)) (1.6.0.post3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow->-r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow->-r requirements.txt (line 5)) (3.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.5->boto3->transformers==2.5.1->-r requirements.txt (line 3)) (2.8.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.5->boto3->transformers==2.5.1->-r requirements.txt (line 3)) (0.15.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow->-r requirements.txt (line 5)) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow->-r requirements.txt (line 5)) (4.1.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow->-r requirements.txt (line 5)) (4.6)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow->-r requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow->-r requirements.txt (line 5)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow->-r requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow->-r requirements.txt (line 5)) (3.1.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=4e4f6dc4cf36d94a0fbc900630aab869c97f74f61fe032bb7bc9f814c9b5b4c3
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: pytorch-ignite, tokenizers, sacremoses, sentencepiece, transformers, tensorboardX
# Successfully installed pytorch-ignite-0.3.0 sacremoses-0.0.43 sentencepiece-0.1.91 tensorboardX-1.8 tokenizers-0.5.2 transformers-2.5.1

# %%
# !python -m spacy download en
# Out:
# Requirement already satisfied: en_core_web_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz#egg=en_core_web_sm==2.2.5 in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.6.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.18.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (47.3.1)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.41.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.2)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.6.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2020.4.5.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
# !python -m torch.distributed.launch --nproc_per_node=8 ./train.py
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-06-23 06:46:08.556335: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-23 06:46:08.587992: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-23 06:46:08.604612: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-23 06:46:08.816912: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-23 06:46:08.867550: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-23 06:46:09.079045: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-23 06:46:09.151079: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-23 06:46:09.220681: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# WARNING:./train.py:Running process 0
# INFO:./train.py:Arguments: Namespace(dataset_cache='./dataset_cache', dataset_path='', device='cpu', eval_before_start=False, fp16='', gradient_accumulation_steps=8, lm_coef=1.0, local_rank=0, lr=6.25e-05, max_history=2, max_norm=1.0, mc_coef=1.0, model_checkpoint='openai-gpt', n_epochs=3, num_candidates=2, personality_permutations=1, train_batch_size=4, valid_batch_size=4)
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
# WARNING:./train.py:Running process 4
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# WARNING:./train.py:Running process 1
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# WARNING:./train.py:Running process 7
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# WARNING:./train.py:Running process 5
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# WARNING:./train.py:Running process 2
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# WARNING:./train.py:Running process 3
# WARNING:./train.py:Running process 6
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/torch/distributed/launch.py", line 263, in <module>
#     main()
#   File "/usr/local/lib/python3.6/dist-packages/torch/distributed/launch.py", line 259, in main
#     cmd=cmd)
# subprocess.CalledProcessError: Command '['/usr/bin/python3', '-u', './train.py', '--local_rank=7']' returned non-zero exit status 1.

# %%
# !python -m torch.distributed.launch --nproc_per_node=8 ./train.py --gradient_accumulation_steps=4 --lm_coef=2.0 --max_history=2 --n_epochs=1 --num_candidates=4 --personality_permutations=2 --train_batch_size=2 --valid_batch_size=2
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-06-23 06:46:53.773924: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-23 06:46:53.839733: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-23 06:46:54.037710: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-23 06:46:54.042617: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-23 06:46:54.096736: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-23 06:46:54.112686: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-23 06:46:54.339698: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-23 06:46:54.364857: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# WARNING:./train.py:Running process 3
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# WARNING:./train.py:Running process 5
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# WARNING:./train.py:Running process 2
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# WARNING:./train.py:Running process 1
# WARNING:./train.py:Running process 0
# INFO:./train.py:Arguments: Namespace(dataset_cache='./dataset_cache', dataset_path='', device='cpu', eval_before_start=False, fp16='', gradient_accumulation_steps=4, lm_coef=2.0, local_rank=0, lr=6.25e-05, max_history=2, max_norm=1.0, mc_coef=1.0, model_checkpoint='openai-gpt', n_epochs=1, num_candidates=4, personality_permutations=2, train_batch_size=2, valid_batch_size=2)
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# WARNING:./train.py:Running process 7
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# WARNING:./train.py:Running process 4
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# WARNING:./train.py:Running process 6
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=47 error=100 : no CUDA-capable device is detected
# Traceback (most recent call last):
#   File "./train.py", line 267, in <module>
#     train()
#   File "./train.py", line 147, in train
#     torch.cuda.set_device(args.local_rank)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 245, in set_device
#     torch._C._cuda_setDevice(device)
#   File "/usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py", line 153, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/torch/distributed/launch.py", line 263, in <module>
#     main()
#   File "/usr/local/lib/python3.6/dist-packages/torch/distributed/launch.py", line 259, in main
#     cmd=cmd)
# subprocess.CalledProcessError: Command '['/usr/bin/python3', '-u', './train.py', '--local_rank=7', '--gradient_accumulation_steps=4', '--lm_coef=2.0', '--max_history=2', '--n_epochs=1', '--num_candidates=4', '--personality_permutations=2', '--train_batch_size=2', '--valid_batch_size=2']' returned non-zero exit status 1.

# %%
# !python ./interact.py --model_checkpoint ./data/Apr17_13-31-38_thunder/
# Out:
# 2020-06-23 06:47:12.613738: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# INFO:./interact.py:Namespace(dataset_cache='./dataset_cache', dataset_path='', device='cpu', max_history=2, max_length=20, min_length=1, model='openai-gpt', model_checkpoint='./data/Apr17_13-31-38_thunder/', no_sample=False, seed=0, temperature=0.7, top_k=0, top_p=0.9)
# INFO:./interact.py:Get pretrained model and tokenizer
# INFO:transformers.tokenization_utils:Model name './data/Apr17_13-31-38_thunder/' not found in model shortcut name list (openai-gpt). Assuming './data/Apr17_13-31-38_thunder/' is a path, a model identifier, or url to a directory containing tokenizer files.
# Traceback (most recent call last):
#   File "./interact.py", line 154, in <module>
#     run()
#   File "./interact.py", line 127, in run
#     tokenizer = tokenizer_class.from_pretrained(args.model_checkpoint)
#   File "/usr/local/lib/python3.6/dist-packages/transformers/tokenization_utils.py", line 390, in from_pretrained
#     return cls._from_pretrained(*inputs, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/transformers/tokenization_utils.py", line 493, in _from_pretrained
#     list(cls.vocab_files_names.values()),
# OSError: Model name './data/Apr17_13-31-38_thunder/' was not found in tokenizers model name list (openai-gpt). We assumed './data/Apr17_13-31-38_thunder/' was a path, a model identifier, or url to a directory containing vocabulary files named ['vocab.json', 'merges.txt'] but couldn't find such vocabulary files at this path or url.

# %%
# !python ./interact.py
# Out:
# 2020-06-23 06:47:28.248571: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# INFO:./interact.py:Namespace(dataset_cache='./dataset_cache', dataset_path='', device='cpu', max_history=2, max_length=20, min_length=1, model='openai-gpt', model_checkpoint='', no_sample=False, seed=0, temperature=0.7, top_k=0, top_p=0.9)
# INFO:filelock:Lock 139644198342608 acquired on /root/.cache/torch/transformers/2f5114b5eb72f9515802779c42c1b289bebdb1cfc8ce94c653237518eb530b34.75f2a4fe69178ff43138117a977e107a5fc7d402603a0825a296b531f246b3f2.lock
# INFO:transformers.file_utils:https://s3.amazonaws.com/models.huggingface.co/transfer-learning-chatbot/gpt_personachat_cache.tar.gz not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmp_7a_6frw
# Downloading: 100% 434M/434M [00:12<00:00, 36.1MB/s]
# INFO:transformers.file_utils:storing https://s3.amazonaws.com/models.huggingface.co/transfer-learning-chatbot/gpt_personachat_cache.tar.gz in cache at /root/.cache/torch/transformers/2f5114b5eb72f9515802779c42c1b289bebdb1cfc8ce94c653237518eb530b34.75f2a4fe69178ff43138117a977e107a5fc7d402603a0825a296b531f246b3f2
# INFO:transformers.file_utils:creating metadata file for /root/.cache/torch/transformers/2f5114b5eb72f9515802779c42c1b289bebdb1cfc8ce94c653237518eb530b34.75f2a4fe69178ff43138117a977e107a5fc7d402603a0825a296b531f246b3f2
# INFO:filelock:Lock 139644198342608 released on /root/.cache/torch/transformers/2f5114b5eb72f9515802779c42c1b289bebdb1cfc8ce94c653237518eb530b34.75f2a4fe69178ff43138117a977e107a5fc7d402603a0825a296b531f246b3f2.lock
# INFO:/content/transfer-learning-conv-ai/utils.py:extracting archive file /root/.cache/torch/transformers/2f5114b5eb72f9515802779c42c1b289bebdb1cfc8ce94c653237518eb530b34.75f2a4fe69178ff43138117a977e107a5fc7d402603a0825a296b531f246b3f2 to temp dir /tmp/tmpwedeicpk
# INFO:./interact.py:Get pretrained model and tokenizer
# INFO:transformers.tokenization_utils:Model name '/tmp/tmpwedeicpk' not found in model shortcut name list (openai-gpt). Assuming '/tmp/tmpwedeicpk' is a path, a model identifier, or url to a directory containing tokenizer files.
# INFO:transformers.tokenization_utils:Didn't find file /tmp/tmpwedeicpk/special_tokens_map.json. We won't load it.
# INFO:transformers.tokenization_utils:Didn't find file /tmp/tmpwedeicpk/tokenizer_config.json. We won't load it.
# INFO:transformers.tokenization_utils:loading file /tmp/tmpwedeicpk/vocab.json
# INFO:transformers.tokenization_utils:loading file /tmp/tmpwedeicpk/merges.txt
# INFO:transformers.tokenization_utils:loading file /tmp/tmpwedeicpk/added_tokens.json
# INFO:transformers.tokenization_utils:loading file None
# INFO:transformers.tokenization_utils:loading file None
# WARNING:transformers.tokenization_openai:ftfy or spacy is not installed using BERT BasicTokenizer instead of SpaCy & ftfy.
# INFO:transformers.configuration_utils:loading configuration file /tmp/tmpwedeicpk/config.json
# INFO:transformers.configuration_utils:Model config OpenAIGPTConfig {
#   "afn": "gelu",
#   "architectures": null,
#   "attn_pdrop": 0.1,
#   "bos_token_id": null,
#   "do_sample": false,
#   "embd_pdrop": 0.1,
#   "eos_token_ids": null,
#   "finetuning_task": null,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "is_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_epsilon": 1e-05,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "model_type": "openai-gpt",
#   "n_ctx": 512,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_layer": 12,
#   "n_positions": 512,
#   "n_special": 5,
#   "num_beams": 1,
#   "num_labels": 2,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": null,
#   "predict_special_tokens": true,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "resid_pdrop": 0.1,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "use_bfloat16": false,
#   "vocab_size": 40483
# }
#
# INFO:transformers.modeling_utils:loading weights file /tmp/tmpwedeicpk/pytorch_model.bin
# INFO:transformers.modeling_utils:Weights from pretrained model not used in OpenAIGPTLMHeadModel: ['multiple_choice_head.summary.weight', 'multiple_choice_head.summary.bias']
# INFO:transformers.tokenization_utils:Assigning <bos> to the bos_token key of the tokenizer
# INFO:transformers.tokenization_utils:Assigning <eos> to the eos_token key of the tokenizer
# INFO:transformers.tokenization_utils:Assigning <pad> to the pad_token key of the tokenizer
# INFO:transformers.tokenization_utils:Assigning ['<speaker1>', '<speaker2>'] to the additional_special_tokens key of the tokenizer
# INFO:./interact.py:Sample a personality
# INFO:/content/transfer-learning-conv-ai/utils.py:Download dataset from https://s3.amazonaws.com/datasets.huggingface.co/personachat/personachat_self_original.json
# INFO:filelock:Lock 139644171404568 acquired on /root/.cache/torch/transformers/a6af0e86c91c9dc9b342b96c59adf0d1a4a7dc602d94b01ad47e0bfd19266632.bb42905dd6e1098e87c24845469ee12018cfd142e10fcc50f97b28e002a9ac02.lock
# INFO:transformers.file_utils:https://s3.amazonaws.com/datasets.huggingface.co/personachat/personachat_self_original.json not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmpxv89bq40
# Downloading: 100% 210M/210M [00:06<00:00, 32.4MB/s]
# INFO:transformers.file_utils:storing https://s3.amazonaws.com/datasets.huggingface.co/personachat/personachat_self_original.json in cache at /root/.cache/torch/transformers/a6af0e86c91c9dc9b342b96c59adf0d1a4a7dc602d94b01ad47e0bfd19266632.bb42905dd6e1098e87c24845469ee12018cfd142e10fcc50f97b28e002a9ac02
# INFO:transformers.file_utils:creating metadata file for /root/.cache/torch/transformers/a6af0e86c91c9dc9b342b96c59adf0d1a4a7dc602d94b01ad47e0bfd19266632.bb42905dd6e1098e87c24845469ee12018cfd142e10fcc50f97b28e002a9ac02
# INFO:filelock:Lock 139644171404568 released on /root/.cache/torch/transformers/a6af0e86c91c9dc9b342b96c59adf0d1a4a7dc602d94b01ad47e0bfd19266632.bb42905dd6e1098e87c24845469ee12018cfd142e10fcc50f97b28e002a9ac02.lock
# INFO:/content/transfer-learning-conv-ai/utils.py:Tokenize and encode the dataset
# hi
# INFO:./interact.py:Selected personality: my favorite drink is pepsi. hotdogs are my favorite food. i like reading horror novels. i work as a librarian. my weekends are filled with bird watching.
# >>> hey there, how are you?
# >>> i am very well!
# i'm great! what do you do for work?
# >>> what is your name
# my name is ryan. i am a librarian.
# >>> do you read?
# i do. do you like reading?
# >>> yes I do
# i am a librarian
# >>> recommend me some books
# do you work?
# >>> no
# i work as a librarian
# >>> recommend me some books
# i'm a librarian
# >>> Traceback (most recent call last):
#   File "./interact.py", line 154, in <module>
#     run()
#   File "./interact.py", line 140, in run
#     raw_text = input(">>> ")
# KeyboardInterrupt
# ^C
